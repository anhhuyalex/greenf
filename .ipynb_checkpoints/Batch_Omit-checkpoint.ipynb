# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from collections import OrderedDict

energy = 10 # np.random.uniform(-1, 1) 
imag = 0.1j
N=20
x_, y_, z_ = (11,16,13)
print("Saving to file", 'greenfs-{}-{}-{}.pickle'.format(x_, y_, z_))

mapping, inv_mapping = [], []

import sys

# class Logger(object):
#     def __init__(self):
#         self.terminal = sys.stdout
#         self.log = open("log.dat", "a")

#     def write(self, message):
#         self.terminal.write(message)
#         self.log.write(message)  

# sys.stdout = Logger()

def generate_triples(N, total):
    # List containing generated triples
    gen = []

    
    if 0 <= total <= N - 1:
        # Generate first element
        i, j, k = (0, 0, total)
        while i <= total:
            # print ("now i is", i)
            while j <= total - i:
                gen.append ((i, j, k))
                j += 1
                k -= 1
            i += 1
            j = 0
            k = total - i
            
                # pass

    elif N <= total <= 2*N - 3:
        # Generate first element
        i, j, k = (0, total-N+1, N-1)
        while i <= N-1:
            while j <= min(N-1, total - i):
                gen.append ((i, j, k))
                j += 1
                k -= 1
            i += 1
            k = min(N-1, total - i)
            j = total - i - k


            
    elif 2*N - 2 <= total <= 3*N - 3:
        # Generate first element
        i, j, k = (total - 2*N + 2, N-1, N-1)
        while i <= N-1:
            while j <= min(N-1, total - i):
                gen.append ((i, j, k))
                j += 1
                k -= 1
            i += 1
            k = min(N-1, total - i)
            j = total - i - k
        
    else:
        raise ValueError("Not applicable k")

    return gen

def index_triple_maps(N):
    mapping = {}
    inv_mapping = {}
    for k in range(3*N - 2):
        triples = generate_triples(N, k)
        coords = OrderedDict()
        inv_coords = OrderedDict()
        for i in range(len(triples)):
            coords[i] = triples[i]
            inv_coords[triples[i]] = i
        mapping[k] = coords
        inv_mapping[k] = inv_coords
    return mapping, inv_mapping

def omit_sites(inv_mapping, omit):
    print ("Omitting", (omit).shape[0] - np.sum(omit), "sites")    
    site = 0
    new_inv_map = {}
    new_map = {}
    
    for sum_ in inv_mapping.keys():
        inv_sum_k_sites = OrderedDict()
        sum_k_sites = OrderedDict()
        site_index = 0
        for triple in inv_mapping[sum_].keys():
            if omit[site] == 1:
                inv_sum_k_sites[triple] = site_index
                sum_k_sites[site_index] = triple
                site_index += 1
            else:
                x, y, z = triple
                # print ("I'm omitting", triple)
            site += 1
        new_inv_map[sum_] = inv_sum_k_sites
        new_map[sum_] = sum_k_sites

    return new_map, new_inv_map, x, y, z

def _calculate(z_n, x_, y_, z_, x_o, y_o, z_o, t_n = 1.0, e_n = 1.0, N = 20, k = 1, c = complex,
                           mapping = mapping, inv_mapping = inv_mapping):

    

    amplitude = t_n / (z_n - e_n)
    # amplitude = 1
    a = {}
    b = {}

    # tic = time.time()
    for k in range(3*N-2):
        alpha_num_entries = len(inv_mapping[k-1]) if k > 0 else 0
        my_entries = len(inv_mapping[k])
        beta_num_entries = len(inv_mapping[k+1]) if k < 3*N - 3 else 0
        a_k = np.zeros((my_entries, alpha_num_entries), dtype=c)
        b_k = np.zeros((my_entries, beta_num_entries), dtype=c)
        for index, triple in mapping[k].items():
            x, y, z = triple

            # Calculate b_k
            if k < 3*N - 3:
                if x < N - 1:
                    try:
                        b_k[index, inv_mapping[k + 1][x + 1, y, z]] = amplitude
                    except:
                        pass
                    
                if y < N - 1:
                    try:
                        b_k[index, inv_mapping[k + 1][x, y + 1, z]] = amplitude
                    except:
                        pass

                if z < N - 1:
                    try:
                        b_k[index, inv_mapping[k + 1][x, y, z + 1]] = amplitude
                    except:
                        pass
#             # Calculate a_k
            if 0 < k:
                if x > 0:
                    try:
                        a_k[index, inv_mapping[k - 1][x - 1, y, z]] = amplitude
                    except:
                        pass

                if y > 0:
                    try:
                        a_k[index, inv_mapping[k - 1][x, y - 1, z]] = amplitude
                    except:
                        pass

                if z > 0:
                    try:
                        a_k[index, inv_mapping[k - 1][x, y, z - 1]] = amplitude
                    except:
                        pass

        a[k] = a_k
        b[k] = b_k
    # toc = time.time()
    # print ("Time building a, b matrices", toc - tic)

    # Calculate C
    sum_ = sum([x_, y_, z_])
    
    C = np.zeros(shape = (len(inv_mapping[sum_]), 1), dtype = complex)
    C[inv_mapping[sum_][(x_, y_, z_)]] = 1. / (z_n - e_n)
    
        



    # Calculate Multiplicative Factors 
    A = {}
    G = {}
    A[1] = b[1]
    tic = time.time()
    for k in range(2, sum_):
        A[k] = np.linalg.solve(np.eye(len(inv_mapping[k])) - a[k].dot(A[k - 1]), b[k])


    A[3*N - 4] = a[3*N - 4]
    for k in range(3*N - 5, sum_, -1):
        A[k] = np.linalg.solve(np.eye(len(inv_mapping[k])) - b[k].dot(A[k + 1]), a[k])

    
    # Calculate Green's Functions
    V = OrderedDict()
    k = sum_
    if 1 < k < 3*N-4:
        V[k] = np.linalg.solve(np.eye(len(inv_mapping[k])) - a[k].dot(A[k - 1]) - b[k].dot(A[k + 1]), 
                            C)
    elif k == 1:
        V[k] = np.linalg.solve(np.eye(len(inv_mapping[k])) - b[k].dot(A[k + 1]), 
                            C)
    elif k == 3*N - 4:
        V[k] = np.linalg.solve(np.eye(len(inv_mapping[k])) - a[k].dot(A[k - 1]), 
                            C)
            
    
    # if x_t + y_t + z_t > sum_:
    for k in range(sum_ + 1, 3*N - 3):
        V[k] = A[k].dot(V[k - 1])
    # elif x_t + y_t + z_t < sum_:
    for k in range(sum_ - 1, 0, -1):
        V[k] = A[k].dot(V[k + 1])

    # return V[x_t + y_t + z_t]
    toc = time.time()
    print ("Time doing lin alg", toc - tic)
    return V
# Out:
# Saving to file greenfs-11-16-13.pickle

# %%
mapping, inv_mapping = index_triple_maps(N)
true_value = (_calculate(energy+imag, x_, y_, z_, 1, 1, 1, mapping = mapping, inv_mapping = inv_mapping))
true_value = true_value[sum([x_, y_, z_])][inv_mapping[sum([x_, y_, z_])][(x_, y_, z_)]]
greenfs = OrderedDict()  
greenfs["true_value"] = true_value
threshold = 0.01
# Out:
# Time doing lin alg 1.5551538467407227

# %%
from collections import OrderedDict

omit = np.full(N**3, 1)

ind = np.arange(N**3)
batches = OrderedDict()
batches[tuple(ind)] = 0

minibatch_size = 300
tic = time.time()
while minibatch_size >= 1:
    # if minibatch_size < 10:
    #     threshold = 0.02
    # elif minibatch_size < 3:
    #     threshold = 0.01
    new_batches = OrderedDict()
    print ([(len(batch), status) for batch, status in batches.items()])
    print ("minibatch_size", minibatch_size)
    for batch, status in batches.items():
        if status == 0:
            dropping = len(batch) // minibatch_size
            
            minibatches = np.array_split(batch, dropping)
            print ("dropping", dropping)
    #         print(np.array_split(batch, dropping))

            for minibatch in minibatches[::-1]:
                
                print ("len(minibatch)", len(minibatch))
                omit[(minibatch)] = 0
                _mapping, _inv_mapping, x_o, y_o, z_o = omit_sites(inv_mapping, omit)

                if ((x_, y_, z_) not in _inv_mapping[sum([x_ + y_ + z_])]):
                    omit[(minibatch)] = 1
                    new_batches[tuple(minibatch)] = 0
                    continue
                if (x_ + y_ + z_ == 3*N - 3) or (x_ + y_ + z_ == 0):
                    continue

                predicted_value = (_calculate(energy+imag, x_, y_, z_, x_o, y_o, z_o, mapping = _mapping, inv_mapping = _inv_mapping))
                predicted_value = predicted_value[sum([x_, y_, z_])][_inv_mapping[sum([x_, y_, z_])][(x_, y_, z_)]]

                rel_err = np.absolute(predicted_value - true_value) / np.absolute(true_value)
                if rel_err > threshold:
                    omit[(minibatch)] = 1
                    print ("Error", rel_err, "over threshold!", threshold)
                    new_batches[tuple(minibatch)] = 0
                else:
                    new_batches[tuple(minibatch)] = 1
                print ("true_value", true_value)
                print ("predicted_value", predicted_value)

        elif status == 1:
            new_batches[tuple(batch)] = 1
            omit[list(batch)] = 0
    
    minibatch_size = minibatch_size / 4
    if 1 < minibatch_size < 2:
        minibatch_size = 1
    batches = new_batches
toc = time.time()
print("Calculation took", toc-tic)
# Out:
# [(8000, 0)]
# minibatch_size 300
# dropping 26
# len(minibatch) 307
# Omitting 307 sites
# Time doing lin alg 1.6674261093139648
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1214022-0.00164265j]
# len(minibatch) 307
# Omitting 614 sites
# Time doing lin alg 1.135099172592163
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12139732-0.00164201j]
# len(minibatch) 307
# Omitting 921 sites
# Time doing lin alg 1.229598045349121
# Error [0.01817842] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11919748-0.00154033j]
# len(minibatch) 307
# Omitting 921 sites
# len(minibatch) 307
# Omitting 921 sites
# Time doing lin alg 1.5186049938201904
# Error [0.04583962] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11584152-0.00141029j]
# len(minibatch) 307
# Omitting 921 sites
# Time doing lin alg 0.7748429775238037
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 307
# Omitting 1228 sites
# Time doing lin alg 0.4917607307434082
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 307
# Omitting 1535 sites
# Time doing lin alg 0.31813883781433105
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 1843 sites
# Time doing lin alg 0.3558530807495117
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 2151 sites
# Time doing lin alg 0.24731087684631348
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 2459 sites
# Time doing lin alg 0.16094684600830078
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 2767 sites
# Time doing lin alg 0.13704919815063477
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 3075 sites
# Time doing lin alg 0.24251413345336914
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 3383 sites
# Time doing lin alg 0.17682790756225586
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 3691 sites
# Time doing lin alg 0.1251840591430664
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 3999 sites
# Time doing lin alg 0.1585538387298584
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 4307 sites
# Time doing lin alg 0.11723875999450684
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 4615 sites
# Time doing lin alg 0.10907888412475586
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 4923 sites
# Time doing lin alg 0.08857274055480957
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 5231 sites
# Time doing lin alg 0.053423166275024414
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 5539 sites
# Time doing lin alg 0.07183694839477539
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 5847 sites
# Time doing lin alg 0.027405977249145508
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 6155 sites
# Time doing lin alg 0.023765087127685547
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 6463 sites
# Time doing lin alg 0.025849103927612305
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 6771 sites
# Time doing lin alg 0.0317990779876709
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# len(minibatch) 308
# Omitting 7079 sites
# Time doing lin alg 0.029655933380126953
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12135296-0.00163752j]
# [(307, 1), (307, 1), (307, 0), (307, 0), (307, 0), (307, 1), (307, 1), (307, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1)]
# minibatch_size 75.0
# dropping 4.0
# len(minibatch) 76
# Omitting 7155 sites
# Time doing lin alg 0.03038477897644043
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12131361-0.00163369j]
# len(minibatch) 77
# Omitting 7232 sites
# Time doing lin alg 0.028827190399169922
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12128275-0.00163145j]
# len(minibatch) 77
# Omitting 7309 sites
# Time doing lin alg 0.01646280288696289
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12091455-0.00160664j]
# len(minibatch) 77
# Omitting 7386 sites
# Time doing lin alg 0.022037982940673828
# Error [0.01851113] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11915722-0.0015364j]
# dropping 4.0
# len(minibatch) 76
# Omitting 7385 sites
# Time doing lin alg 0.020476102828979492
# Error [0.03247437] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11746314-0.00147069j]
# len(minibatch) 77
# Omitting 7386 sites
# Time doing lin alg 0.014306068420410156
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12091367-0.00160653j]
# len(minibatch) 77
# Omitting 7463 sites
# len(minibatch) 77
# Omitting 7463 sites
# Time doing lin alg 0.012752294540405273
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12091367-0.00160653j]
# dropping 4.0
# len(minibatch) 76
# Omitting 7539 sites
# Time doing lin alg 0.009991884231567383
# Error [0.04878724] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11548429-0.00138733j]
# len(minibatch) 77
# Omitting 7540 sites
# Time doing lin alg 0.026224136352539062
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12091367-0.00160653j]
# len(minibatch) 77
# Omitting 7617 sites
# Time doing lin alg 0.08071088790893555
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12091278-0.00160643j]
# len(minibatch) 77
# Omitting 7694 sites
# Time doing lin alg 0.0057048797607421875
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052258-0.00158046j]
# [(307, 1), (307, 1), (76, 1), (77, 1), (77, 1), (77, 0), (76, 0), (77, 1), (77, 0), (77, 1), (76, 0), (77, 1), (77, 1), (77, 1), (307, 1), (307, 1), (307, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1)]
# minibatch_size 18.75
# dropping 4.0
# len(minibatch) 19
# Omitting 7713 sites
# Time doing lin alg 0.006247282028198242
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052258-0.00158046j]
# len(minibatch) 19
# Omitting 7732 sites
# Time doing lin alg 0.014380216598510742
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052258-0.00158046j]
# len(minibatch) 19
# Omitting 7751 sites
# Time doing lin alg 0.005949258804321289
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052258-0.00158046j]
# len(minibatch) 20
# Omitting 7771 sites
# Time doing lin alg 0.020888090133666992
# Error [0.02154487] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11878961-0.00151251j]
# dropping 4.0
# len(minibatch) 19
# Omitting 7770 sites
# Time doing lin alg 0.004006862640380859
# Error [0.03533973] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11711588-0.00144862j]
# len(minibatch) 19
# Omitting 7770 sites
# Time doing lin alg 0.007821083068847656
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052256-0.00158045j]
# len(minibatch) 19
# Omitting 7789 sites
# Time doing lin alg 0.002877950668334961
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052256-0.00158045j]
# len(minibatch) 19
# Omitting 7808 sites
# Time doing lin alg 0.002218008041381836
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12052256-0.00158045j]
# dropping 4.0
# len(minibatch) 19
# Omitting 7827 sites
# len(minibatch) 19
# Omitting 7827 sites
# Time doing lin alg 0.011652946472167969
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203354-0.00156855j]
# len(minibatch) 19
# Omitting 7846 sites
# Time doing lin alg 0.0065517425537109375
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203354-0.00156855j]
# len(minibatch) 20
# Omitting 7866 sites
# Time doing lin alg 0.002151966094970703
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203354-0.00156855j]
# dropping 4.0
# len(minibatch) 19
# Omitting 7885 sites
# Time doing lin alg 0.002958059310913086
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203354-0.00156855j]
# len(minibatch) 19
# Omitting 7904 sites
# Time doing lin alg 0.002942800521850586
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12032782-0.00156788j]
# len(minibatch) 19
# Omitting 7923 sites
# Time doing lin alg 0.003936052322387695
# Error [0.04911282] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11544482-0.00138499j]
# len(minibatch) 19
# Omitting 7923 sites
# Time doing lin alg 0.00635981559753418
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12032782-0.00156788j]
# [(307, 1), (307, 1), (76, 1), (77, 1), (77, 1), (19, 1), (19, 1), (19, 1), (20, 0), (19, 0), (19, 1), (19, 1), (19, 1), (77, 1), (19, 0), (19, 1), (19, 1), (20, 1), (77, 1), (19, 1), (19, 1), (19, 0), (19, 1), (77, 1), (77, 1), (77, 1), (307, 1), (307, 1), (307, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1)]
# minibatch_size 4.6875
# dropping 4.0
# len(minibatch) 5
# Omitting 7928 sites
# Time doing lin alg 0.0025272369384765625
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12032782-0.00156788j]
# len(minibatch) 5
# Omitting 7933 sites
# Time doing lin alg 0.0032978057861328125
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203255-0.00156768j]
# len(minibatch) 5
# Omitting 7938 sites
# Time doing lin alg 0.0034308433532714844
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203255-0.00156768j]
# len(minibatch) 5
# Omitting 7943 sites
# Time doing lin alg 0.0021822452545166016
# Error [0.02305606] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11860648-0.00150098j]
# dropping 4.0
# len(minibatch) 4
# Omitting 7942 sites
# Time doing lin alg 0.0014979839324951172
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203255-0.00156768j]
# len(minibatch) 5
# Omitting 7947 sites
# Time doing lin alg 0.0024209022521972656
# Error [0.03574978] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11706619-0.00144541j]
# len(minibatch) 5
# Omitting 7947 sites
# Time doing lin alg 0.00710606575012207
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203255-0.00156768j]
# len(minibatch) 5
# Omitting 7952 sites
# Time doing lin alg 0.0011336803436279297
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1203255-0.00156768j]
# dropping 4.0
# len(minibatch) 4
# Omitting 7956 sites
# Time doing lin alg 0.00167083740234375
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12023632-0.00156213j]
# len(minibatch) 5
# Omitting 7961 sites
# Time doing lin alg 0.0029578208923339844
# Error [0.01034168] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12014953-0.00155679j]
# len(minibatch) 5
# Omitting 7961 sites
# Time doing lin alg 0.0013709068298339844
# Error [0.01033098] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12015082-0.0015569j]
# len(minibatch) 5
# Omitting 7961 sites
# dropping 4.0
# len(minibatch) 4
# Omitting 7960 sites
# Time doing lin alg 0.0024840831756591797
# Error [0.03692405] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11692386-0.00143688j]
# len(minibatch) 5
# Omitting 7961 sites
# Time doing lin alg 0.001190185546875
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12023632-0.00156213j]
# len(minibatch) 5
# Omitting 7966 sites
# Time doing lin alg 0.002610921859741211
# Error [0.0226983] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11864984-0.00150365j]
# len(minibatch) 5
# Omitting 7966 sites
# Time doing lin alg 0.002605915069580078
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12023632-0.00156213j]
# [(307, 1), (307, 1), (76, 1), (77, 1), (77, 1), (19, 1), (19, 1), (19, 1), (5, 1), (5, 1), (5, 1), (5, 0), (4, 1), (5, 0), (5, 1), (5, 1), (19, 1), (19, 1), (19, 1), (77, 1), (4, 1), (5, 0), (5, 0), (5, 0), (19, 1), (19, 1), (20, 1), (77, 1), (19, 1), (19, 1), (4, 0), (5, 1), (5, 0), (5, 1), (19, 1), (77, 1), (77, 1), (77, 1), (307, 1), (307, 1), (307, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1), (308, 1)]
# minibatch_size 1
# dropping 5
# len(minibatch) 1
# Omitting 7967 sites
# Time doing lin alg 0.015118122100830078
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1202352-0.00156203j]
# len(minibatch) 1
# Omitting 7968 sites
# Time doing lin alg 0.005402088165283203
# Error [0.02320459] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11858847-0.00149996j]
# len(minibatch) 1
# Omitting 7968 sites
# Time doing lin alg 0.0027031898498535156
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12023058-0.00156164j]
# len(minibatch) 1
# Omitting 7969 sites
# Time doing lin alg 0.0021219253540039062
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12023057-0.00156164j]
# len(minibatch) 1
# Omitting 7970 sites
# Time doing lin alg 0.003170013427734375
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12023057-0.00156164j]
# dropping 5
# len(minibatch) 1
# Omitting 7971 sites
# Time doing lin alg 0.005316972732543945
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022944-0.00156154j]
# len(minibatch) 1
# Omitting 7972 sites
# Time doing lin alg 0.0037152767181396484
# Error [0.02323893] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11858432-0.00149961j]
# len(minibatch) 1
# Omitting 7972 sites
# Time doing lin alg 0.001171112060546875
# Error [0.02325471] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11858241-0.00149945j]
# len(minibatch) 1
# Omitting 7972 sites
# Time doing lin alg 0.0016970634460449219
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022827-0.00156144j]
# len(minibatch) 1
# Omitting 7973 sites
# Time doing lin alg 0.002882719039916992
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022827-0.00156144j]
# dropping 5
# len(minibatch) 1
# Omitting 7974 sites
# Time doing lin alg 0.003895998001098633
# Error [0.01037892] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12014502-0.0015564j]
# len(minibatch) 1
# Omitting 7974 sites
# Time doing lin alg 0.004653215408325195
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# len(minibatch) 1
# Omitting 7975 sites
# Time doing lin alg 0.004463911056518555
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# len(minibatch) 1
# Omitting 7976 sites
# Time doing lin alg 0.0010731220245361328
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# len(minibatch) 1
# Omitting 7977 sites
# Time doing lin alg 0.0022270679473876953
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# dropping 5
# len(minibatch) 1
# Omitting 7978 sites
# Time doing lin alg 0.003487825393676758
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# len(minibatch) 1
# Omitting 7979 sites
# Time doing lin alg 0.0032057762145996094
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# len(minibatch) 1
# Omitting 7980 sites
# Time doing lin alg 0.0016391277313232422
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022826-0.00156144j]
# len(minibatch) 1
# Omitting 7981 sites
# Time doing lin alg 0.004748821258544922
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022824-0.00156144j]
# len(minibatch) 1
# Omitting 7982 sites
# Time doing lin alg 0.0023889541625976562
# Error [0.01037892] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12014502-0.0015564j]
# dropping 5
# len(minibatch) 1
# Omitting 7982 sites
# len(minibatch) 1
# Omitting 7982 sites
# Time doing lin alg 0.0032160282135009766
# Error [0.01039662] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12014288-0.00155622j]
# len(minibatch) 1
# Omitting 7982 sites
# Time doing lin alg 0.0016438961029052734
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022823-0.00156144j]
# len(minibatch) 1
# Omitting 7983 sites
# Time doing lin alg 0.008184194564819336
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022823-0.00156144j]
# len(minibatch) 1
# Omitting 7984 sites
# Time doing lin alg 0.002413034439086914
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022823-0.00156144j]
# dropping 4
# len(minibatch) 1
# Omitting 7985 sites
# Time doing lin alg 0.0027320384979248047
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022716-0.00156135j]
# len(minibatch) 1
# Omitting 7986 sites
# Time doing lin alg 0.0035200119018554688
# Error [0.02325065] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1185829-0.00149949j]
# len(minibatch) 1
# Omitting 7986 sites
# Time doing lin alg 0.0026159286499023438
# Error [0.02376468] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.1185206-0.00149573j]
# len(minibatch) 1
# Omitting 7986 sites
# Time doing lin alg 0.0013430118560791016
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022607-0.00156125j]
# dropping 5
# len(minibatch) 1
# Omitting 7987 sites
# Time doing lin alg 0.0014278888702392578
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022607-0.00156125j]
# len(minibatch) 1
# Omitting 7988 sites
# Time doing lin alg 0.00455927848815918
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022607-0.00156125j]
# len(minibatch) 1
# Omitting 7989 sites
# Time doing lin alg 0.001960277557373047
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022503-0.00156117j]
# len(minibatch) 1
# Omitting 7990 sites
# Time doing lin alg 0.0031158924102783203
# Error [0.02277055] over threshold! 0.01
# true_value [0.12140221-0.00164265j]
# predicted_value [0.11864109-0.00150291j]
# len(minibatch) 1
# Omitting 7990 sites
# Time doing lin alg 0.0022029876708984375
# true_value [0.12140221-0.00164265j]
# predicted_value [0.12022397-0.00156108j]
# Calculation took 12.306020975112915

# %%
def gen_triples(N):
    i, j, k = (0, 0, 0)
    coords = []
    for i in range(N):
        for j in range(N):
            for k in range(N):
                coords.append((i,j,k))

    return coords


coords = gen_triples(N)
state_mapping = {i: coords[i] for i in range(len(coords))}
inv_state_mapping = {coords[i]: i for i in range(len(coords))}

# for state in np.where(omit)[0]:
#     omit = np.full(N**3, 1)
#     omit[state] = 0
#     _mapping, _inv_mapping, x_o, y_o, z_o = omit_sites(inv_mapping, omit)
#     print(x_o, y_o, z_o)
# Out:
# Omitting 1 sites
# 10 16 13
# Omitting 1 sites
# 11 15 13
# Omitting 1 sites
# 11 16 12
# Omitting 1 sites
# 11 15 14
# Omitting 1 sites
# 11 16 13
# Omitting 1 sites
# 11 17 12
# Omitting 1 sites
# 12 15 13
# Omitting 1 sites
# 11 16 14
# Omitting 1 sites
# 11 17 13
# Omitting 1 sites
# 12 16 13

# %%
imaginary = 0.1j
real1, imagin1 = [], []
_mapping, _inv_mapping, x_o, y_o, z_o = omit_sites(inv_mapping, omit)
for z in np.linspace(0, 10, 100):
    true_value = (_calculate(z+imaginary, x_, y_, z_, x_o, y_o, z_o, mapping = mapping, inv_mapping = inv_mapping))
    true_value = true_value[sum([x_, y_, z_])][_inv_mapping[sum([x_, y_, z_])][(x_, y_, z_)]]
    predicted_value = (_calculate(z+imaginary, x_, y_, z_, x_o, y_o, z_o, mapping = _mapping, inv_mapping = _inv_mapping))
    predicted_value = predicted_value[sum([x_, y_, z_])][_inv_mapping[sum([x_, y_, z_])][(x_, y_, z_)]]
    real1.append(np.real(predicted_value))
    imagin1.append(np.imag(predicted_value))
# Out:
# Omitting 7990 sites
# Time doing lin alg 0.0019791126251220703
# Time doing lin alg 0.002330780029296875
# Time doing lin alg 0.0028159618377685547
# Time doing lin alg 0.0023479461669921875
# Time doing lin alg 0.0022361278533935547
# Time doing lin alg 0.0018150806427001953
# Time doing lin alg 0.001789093017578125
# Time doing lin alg 0.002240896224975586
# Time doing lin alg 0.004110097885131836
# Time doing lin alg 0.0019812583923339844
# Time doing lin alg 0.0022249221801757812
# Time doing lin alg 0.001852273941040039
# Time doing lin alg 0.0021767616271972656
# Time doing lin alg 0.0025119781494140625
# Time doing lin alg 0.002179861068725586
# Time doing lin alg 0.0017781257629394531
# Time doing lin alg 0.002292156219482422
# Time doing lin alg 0.0018322467803955078
# Time doing lin alg 0.0017757415771484375
# Time doing lin alg 0.002299785614013672
# Time doing lin alg 0.002170085906982422
# Time doing lin alg 0.0022940635681152344
# Time doing lin alg 0.0021266937255859375
# Time doing lin alg 0.002214193344116211
# Time doing lin alg 0.0018131732940673828
# Time doing lin alg 0.002336263656616211
# Time doing lin alg 0.0025169849395751953
# Time doing lin alg 0.0017549991607666016
# Time doing lin alg 0.0017712116241455078
# Time doing lin alg 0.0017590522766113281
# Time doing lin alg 0.0017390251159667969
# Time doing lin alg 0.0024662017822265625
# Time doing lin alg 0.002029895782470703
# Time doing lin alg 0.001983165740966797
# Time doing lin alg 0.0018420219421386719
# Time doing lin alg 0.0019040107727050781
# Time doing lin alg 0.0017349720001220703
# Time doing lin alg 0.001967191696166992
# Time doing lin alg 0.001911163330078125
# Time doing lin alg 0.0020499229431152344
# Time doing lin alg 0.0024149417877197266
# Time doing lin alg 0.0018057823181152344
# Time doing lin alg 0.0018181800842285156
# Time doing lin alg 0.0017240047454833984
# Time doing lin alg 0.0017731189727783203
# Time doing lin alg 0.0017731189727783203
# Time doing lin alg 0.0018649101257324219
# Time doing lin alg 0.0018639564514160156
# Time doing lin alg 0.0021369457244873047
# Time doing lin alg 0.017285823822021484
# Time doing lin alg 0.0019867420196533203
# Time doing lin alg 0.0019049644470214844
# Time doing lin alg 0.001764059066772461
# Time doing lin alg 0.0018649101257324219
# Time doing lin alg 0.0018208026885986328
# Time doing lin alg 0.001728057861328125
# Time doing lin alg 0.005667924880981445
# Time doing lin alg 0.0016682147979736328
# Time doing lin alg 0.0031349658966064453
# Time doing lin alg 0.00196075439453125
# Time doing lin alg 0.004734039306640625
# Time doing lin alg 0.0018639564514160156
# Time doing lin alg 0.0019049644470214844
# Time doing lin alg 0.005644083023071289
# Time doing lin alg 0.02107691764831543
# Time doing lin alg 0.02695298194885254
# Time doing lin alg 0.019540786743164062
# Time doing lin alg 0.0034639835357666016
# Time doing lin alg 0.016777992248535156
# Time doing lin alg 0.0021049976348876953
# Time doing lin alg 0.0030450820922851562
# Time doing lin alg 0.002007007598876953
# Time doing lin alg 0.0020699501037597656
# Time doing lin alg 0.0019099712371826172
# Time doing lin alg 0.003959178924560547
# Time doing lin alg 0.0021200180053710938
# Time doing lin alg 0.03958392143249512
# Time doing lin alg 0.0017647743225097656
# Time doing lin alg 0.0017962455749511719
# Time doing lin alg 0.0031638145446777344
# Time doing lin alg 0.0023040771484375
# Time doing lin alg 0.0025856494903564453
# Time doing lin alg 0.001886129379272461
# Time doing lin alg 0.0018661022186279297
# Time doing lin alg 0.0019271373748779297
# Time doing lin alg 0.01247096061706543
# Time doing lin alg 0.0018410682678222656
# Time doing lin alg 0.0034542083740234375
# Time doing lin alg 0.0038330554962158203
# Time doing lin alg 0.0017879009246826172
# Time doing lin alg 0.0019412040710449219
# Time doing lin alg 0.0018510818481445312
# Time doing lin alg 0.0017809867858886719
# Time doing lin alg 0.011034727096557617
# Time doing lin alg 0.0017650127410888672
# Time doing lin alg 0.008352041244506836
# Time doing lin alg 0.0018248558044433594
# Time doing lin alg 0.002148866653442383
# Time doing lin alg 0.0018591880798339844
# Time doing lin alg 0.0017747879028320312

# %%
plt.plot(np.linspace(0, 10, 100), real)
plt.plot(np.linspace(0, 10, 100), real1)
plt.show()
plt.plot(np.linspace(0, 10, 100), imagin)
plt.plot(np.linspace(0, 10, 100), imagin1)
plt.show()

# %%
predicted_value

# %%
dropping = len(batch) // minibatch_size
            
minibatches = np.array_split(batch, dropping)
print ("dropping", dropping)
#         print(np.array_split(batch, dropping))

for minibatch in minibatches[::-1]:

    print ("len(minibatch)", len(minibatch))
    omit[(minibatch)] = 0
    _mapping, _inv_mapping, x_o, y_o, z_o = omit_sites(inv_mapping, omit)

    if ((x_, y_, z_) not in _inv_mapping[sum([x_ + y_ + z_])]):
        omit[(minibatch)] = 1
        new_batches[tuple(minibatch)] = 0
        continue
    if (x_ + y_ + z_ == 3*N - 3) or (x_ + y_ + z_ == 0):
        continue

    predicted_value = (_calculate(energy+imag, x_, y_, z_, x_o, y_o, z_o, mapping = _mapping, inv_mapping = _inv_mapping))
    predicted_value = predicted_value[sum([x_, y_, z_])][_inv_mapping[sum([x_, y_, z_])][(x_, y_, z_)]]

    rel_err = np.absolute(predicted_value - true_value) / np.absolute(true_value)
    if rel_err > threshold:
        omit[(minibatch)] = 1
        print ("Error", rel_err, "over threshold!", threshold)
        new_batches[tuple(minibatch)] = 0
    else:
        new_batches[tuple(minibatch)] = 1
    print ("true_value", true_value)
    print ("predicted_value", predicted_value)
# Out:
# 7999
